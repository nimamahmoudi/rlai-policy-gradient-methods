# %% [markdown]
# # Trying Different Configurations for REINFORCE with baseline
#
# In this notebook, we will try out different configurations and plot the performance of the agent vs those configurations.

# %%
# import needed libs

# %load_ext autoreload

# Auto reloading causes the kernel to reload the libraries we have
# %autoreload 2

# usual imports for visualization, etc.
import numpy as np
import matplotlib.pyplot as plt

import datetime

# make it reproducible
np.random.seed(0)

# show plots inline
# %matplotlib inline

# %%
# Some initializations

from envs import SmartVac
from agents import ReinforceWithBaselineAgent

max_episode_steps = 100
results_folder = 'res/'
figs_folder = 'figs/'

# %%
AgentClass = ReinforceWithBaselineAgent

alpha_base = 2
alpha_pows_w = np.linspace(-6, 0, 4)
alpha_pows_theta = np.linspace(-14, 0, 15)
alphas_w = np.power(alpha_base, alpha_pows_w)
alphas_theta = np.power(alpha_base, alpha_pows_theta)
print(alphas_w)
print(alphas_theta)

best_performance = 0.63
env = SmartVac()
num_of_tests = 5
episode_count = 10000
plot_count = int(episode_count / 100)

agent_name = AgentClass.__name__

results = ""
all_best_avgs = []
all_best_alpha_thetas = []
all_total_avgs = []
all_total_bests = []
all_total_lasts = []
for alpha_pow_w in alpha_pows_w:
    all_avgs = []
    all_bests = []
    all_lasts = []
    alpha_w = np.power(alpha_base, alpha_pow_w)
    for alpha_pow_theta in alpha_pows_theta:
        alpha_theta = np.power(alpha_base, alpha_pow_theta)
        params_str = f'alpha_w_{alpha_w}_alpha_theta_{alpha_theta}_episodes_{episode_count}'
        mult_avgs = []
        for i_test in range(num_of_tests):
            print()
            print(i_test + 1, end=' ')

            # Initialize the agent
            agent = AgentClass(alpha_theta=alpha_theta, alpha_w=alpha_w)

            avgs = []
            probs1 = []
            probs2 = []

            episode_rewards = np.zeros(episode_count)
            for i_episode in range(episode_count):
                done = False
                totalReward = 0

                if i_episode >= plot_count and (i_episode % plot_count == 0):
                    avg = np.average(episode_rewards[i_episode - plot_count:i_episode])
                    avgs.append(avg)

                    # deterministic position
                    env.x = 0
                    env.y = 1
                    obs = env.get_obs()
                    prob = agent.get_action_vals_for_obs(obs)
                    probs1.append(prob)

                    # stochastic position
                    env.x = 1
                    env.y = 1
                    obs = env.get_obs()
                    prob = agent.get_action_vals_for_obs(obs)
                    probs2.append(prob)

                    print('#', end='', flush=True)
                    if len(avgs) % 100 == 0:
                        print(i_episode)

                obs = env.reset()
                action = agent.start(obs)

                step = 0
                while not done:
                    obs, reward, done = env.step(action)
                    action = agent.step(obs, reward, done)
                    totalReward += reward

                    step += 1
                    if step > max_episode_steps:
                        done = True

                episode_rewards[i_episode] = totalReward
                agent.update_for_episode()

            mult_avgs.append(avgs)

        avgs = np.mean(np.array(mult_avgs), axis=0)

        all_avgs.append(np.mean(avgs))
        all_bests.append(np.max(avgs))
        all_lasts.append(avgs[-1])

        results_tmp = f'\n\nAgent: {agent_name} \tAlpha_w: {alpha_w}\tAlpha_theta: {alpha_theta}'
        results_tmp += f'\nAverage: \t\t{np.mean(avgs):5.3f}'
        results_tmp += f'\nBest {plot_count} Average: \t{np.max(avgs):5.3f}'
        results_tmp += f'\nLast {plot_count} Average: \t{avgs[-1]:5.3f}'
        print(results_tmp)

        results += results_tmp
        
    # print best results
    all_avgs = np.array(all_avgs)
    idx = np.argmax(all_avgs)
    all_best_avgs.append(all_avgs[idx])
    all_best_alpha_thetas.append(alphas_theta[idx])
    
    # Save for plotting
    all_total_avgs.append(all_avgs)
    all_total_bests.append(all_bests)
    all_total_lasts.append(all_lasts)
    
# Print best results
all_best_avgs = np.array(all_best_avgs)
idx = np.argmax(all_best_avgs)
results += f'\n\n\nBest Average: {all_best_avgs[idx]}'
results += f'\nConfig: Alpha_w={alphas_w[idx]}, Alpha_theta={all_best_alpha_thetas[idx]}'

print('')
print(results)
# with open(f'{results_folder}agent_{agent_name}_all_mult.txt', 'w') as file:
#     file.write(results)
# Out:
# [0.015625 0.0625   0.25     1.      ]
# [6.10351562e-05 1.22070312e-04 2.44140625e-04 4.88281250e-04
#  9.76562500e-04 1.95312500e-03 3.90625000e-03 7.81250000e-03
#  1.56250000e-02 3.12500000e-02 6.25000000e-02 1.25000000e-01
#  2.50000000e-01 5.00000000e-01 1.00000000e+00]
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 6.103515625e-05
# Average: 			-0.941
# Best 100 Average: 	-0.796
# Last 100 Average: 	-0.856
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0001220703125
# Average: 			-0.871
# Best 100 Average: 	-0.662
# Last 100 Average: 	-0.778
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.000244140625
# Average: 			-0.755
# Best 100 Average: 	-0.453
# Last 100 Average: 	-0.459
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00048828125
# Average: 			-0.574
# Best 100 Average: 	-0.241
# Last 100 Average: 	-0.277
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0009765625
# Average: 			-0.380
# Best 100 Average: 	0.042
# Last 100 Average: 	-0.002
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.001953125
# Average: 			-0.114
# Best 100 Average: 	0.323
# Last 100 Average: 	0.323
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00390625
# Average: 			0.140
# Best 100 Average: 	0.502
# Last 100 Average: 	0.415
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0078125
# Average: 			0.323
# Best 100 Average: 	0.566
# Last 100 Average: 	0.515
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.015625
# Average: 			0.446
# Best 100 Average: 	0.596
# Last 100 Average: 	0.562
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.03125
# Average: 			0.514
# Best 100 Average: 	0.611
# Last 100 Average: 	0.600
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0625
# Average: 			0.555
# Best 100 Average: 	0.633
# Last 100 Average: 	0.627
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.125
# Average: 			0.581
# Best 100 Average: 	0.637
# Last 100 Average: 	0.594
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.25
# Average: 			-12.313
# Best 100 Average: 	0.308
# Last 100 Average: 	-15.721
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.5
# Average: 			-0.596
# Best 100 Average: 	0.060
# Last 100 Average: 	-0.086
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 1.0
# Average: 			-8.156
# Best 100 Average: 	-4.895
# Last 100 Average: 	-7.957
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 6.103515625e-05
# Average: 			-0.948
# Best 100 Average: 	-0.727
# Last 100 Average: 	-0.821
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0001220703125
# Average: 			-0.873
# Best 100 Average: 	-0.601
# Last 100 Average: 	-0.675
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.000244140625
# Average: 			-0.745
# Best 100 Average: 	-0.431
# Last 100 Average: 	-0.552
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00048828125
# Average: 			-0.583
# Best 100 Average: 	-0.250
# Last 100 Average: 	-0.250
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0009765625
# Average: 			-0.361
# Best 100 Average: 	-0.005
# Last 100 Average: 	-0.029
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.001953125
# Average: 			-0.114
# Best 100 Average: 	0.310
# Last 100 Average: 	0.240
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00390625
# Average: 			0.153
# Best 100 Average: 	0.486
# Last 100 Average: 	0.463
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0078125
# Average: 			0.320
# Best 100 Average: 	0.556
# Last 100 Average: 	0.516
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.015625
# Average: 			0.443
# Best 100 Average: 	0.603
# Last 100 Average: 	0.573
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.03125
# Average: 			0.513
# Best 100 Average: 	0.629
# Last 100 Average: 	0.579
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0625
# Average: 			0.552
# Best 100 Average: 	0.629
# Last 100 Average: 	0.584
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.125
# Average: 			0.575
# Best 100 Average: 	0.630
# Last 100 Average: 	0.594
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.25
# Average: 			-7.731
# Best 100 Average: 	0.584
# Last 100 Average: 	-18.257
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ##################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.5
# Average: 			-18.517
# Best 100 Average: 	-0.040
# Last 100 Average: 	-23.739
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 1.0
# Average: 			-0.116
# Best 100 Average: 	0.025
# Last 100 Average: 	-0.077
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 6.103515625e-05
# Average: 			-0.944
# Best 100 Average: 	-0.800
# Last 100 Average: 	-0.919
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0001220703125
# Average: 			-0.874
# Best 100 Average: 	-0.629
# Last 100 Average: 	-0.662
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.000244140625
# Average: 			-0.755
# Best 100 Average: 	-0.456
# Last 100 Average: 	-0.545
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00048828125
# Average: 			-0.582
# Best 100 Average: 	-0.283
# Last 100 Average: 	-0.283
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0009765625
# Average: 			-0.372
# Best 100 Average: 	0.032
# Last 100 Average: 	-0.080
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.001953125
# Average: 			-0.121
# Best 100 Average: 	0.323
# Last 100 Average: 	0.287
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00390625
# Average: 			0.136
# Best 100 Average: 	0.482
# Last 100 Average: 	0.477
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0078125
# Average: 			0.326
# Best 100 Average: 	0.582
# Last 100 Average: 	0.555
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.015625
# Average: 			0.438
# Best 100 Average: 	0.606
# Last 100 Average: 	0.571
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.03125
# Average: 			0.514
# Best 100 Average: 	0.618
# Last 100 Average: 	0.617
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0625
# Average: 			0.554
# Best 100 Average: 	0.633
# Last 100 Average: 	0.603
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.125
# Average: 			0.577
# Best 100 Average: 	0.635
# Last 100 Average: 	0.629
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.25
# Average: 			0.582
# Best 100 Average: 	0.638
# Last 100 Average: 	0.619
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.5
# Average: 			-18.339
# Best 100 Average: 	0.288
# Last 100 Average: 	-40.034
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 1.0
# Average: 			-4.366
# Best 100 Average: 	-2.390
# Last 100 Average: 	-4.449
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 6.103515625e-05
# Average: 			-0.943
# Best 100 Average: 	-0.785
# Last 100 Average: 	-0.899
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0001220703125
# Average: 			-0.867
# Best 100 Average: 	-0.634
# Last 100 Average: 	-0.714
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.000244140625
# Average: 			-0.751
# Best 100 Average: 	-0.487
# Last 100 Average: 	-0.518
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00048828125
# Average: 			-0.590
# Best 100 Average: 	-0.263
# Last 100 Average: 	-0.309
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0009765625
# Average: 			-0.383
# Best 100 Average: 	-0.003
# Last 100 Average: 	-0.056
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.001953125
# Average: 			-0.100
# Best 100 Average: 	0.337
# Last 100 Average: 	0.268
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00390625
# Average: 			0.143
# Best 100 Average: 	0.517
# Last 100 Average: 	0.465
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0078125
# Average: 			0.322
# Best 100 Average: 	0.554
# Last 100 Average: 	0.539
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.015625
# Average: 			0.440
# Best 100 Average: 	0.592
# Last 100 Average: 	0.574
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.03125
# Average: 			0.511
# Best 100 Average: 	0.618
# Last 100 Average: 	0.599
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0625
# Average: 			0.551
# Best 100 Average: 	0.634
# Last 100 Average: 	0.597
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.125
# Average: 			0.570
# Best 100 Average: 	0.635
# Last 100 Average: 	0.614
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.25
# Average: 			0.475
# Best 100 Average: 	0.547
# Last 100 Average: 	0.478
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.5
# Average: 			0.241
# Best 100 Average: 	0.378
# Last 100 Average: 	0.281
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 1.0
# Average: 			0.010
# Best 100 Average: 	0.106
# Last 100 Average: 	0.054
#
#
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 6.103515625e-05
# Average: 			-0.941
# Best 100 Average: 	-0.796
# Last 100 Average: 	-0.856
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0001220703125
# Average: 			-0.871
# Best 100 Average: 	-0.662
# Last 100 Average: 	-0.778
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.000244140625
# Average: 			-0.755
# Best 100 Average: 	-0.453
# Last 100 Average: 	-0.459
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00048828125
# Average: 			-0.574
# Best 100 Average: 	-0.241
# Last 100 Average: 	-0.277
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0009765625
# Average: 			-0.380
# Best 100 Average: 	0.042
# Last 100 Average: 	-0.002
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.001953125
# Average: 			-0.114
# Best 100 Average: 	0.323
# Last 100 Average: 	0.323
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00390625
# Average: 			0.140
# Best 100 Average: 	0.502
# Last 100 Average: 	0.415
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0078125
# Average: 			0.323
# Best 100 Average: 	0.566
# Last 100 Average: 	0.515
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.015625
# Average: 			0.446
# Best 100 Average: 	0.596
# Last 100 Average: 	0.562
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.03125
# Average: 			0.514
# Best 100 Average: 	0.611
# Last 100 Average: 	0.600
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0625
# Average: 			0.555
# Best 100 Average: 	0.633
# Last 100 Average: 	0.627
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.125
# Average: 			0.581
# Best 100 Average: 	0.637
# Last 100 Average: 	0.594
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.25
# Average: 			-12.313
# Best 100 Average: 	0.308
# Last 100 Average: 	-15.721
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.5
# Average: 			-0.596
# Best 100 Average: 	0.060
# Last 100 Average: 	-0.086
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 1.0
# Average: 			-8.156
# Best 100 Average: 	-4.895
# Last 100 Average: 	-7.957
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 6.103515625e-05
# Average: 			-0.948
# Best 100 Average: 	-0.727
# Last 100 Average: 	-0.821
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0001220703125
# Average: 			-0.873
# Best 100 Average: 	-0.601
# Last 100 Average: 	-0.675
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.000244140625
# Average: 			-0.745
# Best 100 Average: 	-0.431
# Last 100 Average: 	-0.552
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00048828125
# Average: 			-0.583
# Best 100 Average: 	-0.250
# Last 100 Average: 	-0.250
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0009765625
# Average: 			-0.361
# Best 100 Average: 	-0.005
# Last 100 Average: 	-0.029
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.001953125
# Average: 			-0.114
# Best 100 Average: 	0.310
# Last 100 Average: 	0.240
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00390625
# Average: 			0.153
# Best 100 Average: 	0.486
# Last 100 Average: 	0.463
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0078125
# Average: 			0.320
# Best 100 Average: 	0.556
# Last 100 Average: 	0.516
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.015625
# Average: 			0.443
# Best 100 Average: 	0.603
# Last 100 Average: 	0.573
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.03125
# Average: 			0.513
# Best 100 Average: 	0.629
# Last 100 Average: 	0.579
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0625
# Average: 			0.552
# Best 100 Average: 	0.629
# Last 100 Average: 	0.584
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.125
# Average: 			0.575
# Best 100 Average: 	0.630
# Last 100 Average: 	0.594
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.25
# Average: 			-7.731
# Best 100 Average: 	0.584
# Last 100 Average: 	-18.257
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.5
# Average: 			-18.517
# Best 100 Average: 	-0.040
# Last 100 Average: 	-23.739
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 1.0
# Average: 			-0.116
# Best 100 Average: 	0.025
# Last 100 Average: 	-0.077
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 6.103515625e-05
# Average: 			-0.944
# Best 100 Average: 	-0.800
# Last 100 Average: 	-0.919
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0001220703125
# Average: 			-0.874
# Best 100 Average: 	-0.629
# Last 100 Average: 	-0.662
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.000244140625
# Average: 			-0.755
# Best 100 Average: 	-0.456
# Last 100 Average: 	-0.545
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00048828125
# Average: 			-0.582
# Best 100 Average: 	-0.283
# Last 100 Average: 	-0.283
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0009765625
# Average: 			-0.372
# Best 100 Average: 	0.032
# Last 100 Average: 	-0.080
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.001953125
# Average: 			-0.121
# Best 100 Average: 	0.323
# Last 100 Average: 	0.287
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00390625
# Average: 			0.136
# Best 100 Average: 	0.482
# Last 100 Average: 	0.477
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0078125
# Average: 			0.326
# Best 100 Average: 	0.582
# Last 100 Average: 	0.555
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.015625
# Average: 			0.438
# Best 100 Average: 	0.606
# Last 100 Average: 	0.571
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.03125
# Average: 			0.514
# Best 100 Average: 	0.618
# Last 100 Average: 	0.617
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0625
# Average: 			0.554
# Best 100 Average: 	0.633
# Last 100 Average: 	0.603
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.125
# Average: 			0.577
# Best 100 Average: 	0.635
# Last 100 Average: 	0.629
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.25
# Average: 			0.582
# Best 100 Average: 	0.638
# Last 100 Average: 	0.619
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.5
# Average: 			-18.339
# Best 100 Average: 	0.288
# Last 100 Average: 	-40.034
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 1.0
# Average: 			-4.366
# Best 100 Average: 	-2.390
# Last 100 Average: 	-4.449
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 6.103515625e-05
# Average: 			-0.943
# Best 100 Average: 	-0.785
# Last 100 Average: 	-0.899
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0001220703125
# Average: 			-0.867
# Best 100 Average: 	-0.634
# Last 100 Average: 	-0.714
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.000244140625
# Average: 			-0.751
# Best 100 Average: 	-0.487
# Last 100 Average: 	-0.518
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00048828125
# Average: 			-0.590
# Best 100 Average: 	-0.263
# Last 100 Average: 	-0.309
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0009765625
# Average: 			-0.383
# Best 100 Average: 	-0.003
# Last 100 Average: 	-0.056
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.001953125
# Average: 			-0.100
# Best 100 Average: 	0.337
# Last 100 Average: 	0.268
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00390625
# Average: 			0.143
# Best 100 Average: 	0.517
# Last 100 Average: 	0.465
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0078125
# Average: 			0.322
# Best 100 Average: 	0.554
# Last 100 Average: 	0.539
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.015625
# Average: 			0.440
# Best 100 Average: 	0.592
# Last 100 Average: 	0.574
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.03125
# Average: 			0.511
# Best 100 Average: 	0.618
# Last 100 Average: 	0.599
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0625
# Average: 			0.551
# Best 100 Average: 	0.634
# Last 100 Average: 	0.597
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.125
# Average: 			0.570
# Best 100 Average: 	0.635
# Last 100 Average: 	0.614
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.25
# Average: 			0.475
# Best 100 Average: 	0.547
# Last 100 Average: 	0.478
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.5
# Average: 			0.241
# Best 100 Average: 	0.378
# Last 100 Average: 	0.281
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 1.0
# Average: 			0.010
# Best 100 Average: 	0.106
# Last 100 Average: 	0.054
#
#
# Best Average: 0.5815676767676768
# Config: Alpha_w=0.25, Alpha_theta=0.25

# %%
plt.figure(2, figsize=(14,10))
plt.semilogx(alphas_theta, np.array(all_total_avgs).T, basex=alpha_base)
plt.title(f'Average Return in {episode_count} episodes')
plt.xlabel('alpha_theta')
plt.ylabel('Average Return')
plt.legend([f'alpha_w={alpha_base}^{alpha_pow:.2f}' for alpha_pow in alpha_pows_w])
plt.axhline(y=best_performance, linewidth=1, color="g", linestyle='--')
plt.ylim(best_performance-2.13,best_performance+.07)
# plt.savefig(f'{figs_folder}agent_{agent_name}_episodes_{episode_count}_all_avg.png')

# There is no meaning in bests plot
# plt.figure(3, figsize=(14,10))
# plt.semilogx(alphas_theta, np.array(all_total_bests).T, basex=alpha_base)
# plt.title(f'Best {plot_count}-episode return average until {episode_count} episodes')
# plt.xlabel('alpha')
# plt.ylabel(f'Best {plot_count}-episode average reward')
# plt.axhline(y=best_performance, linewidth=1, color="g", linestyle='--')
# plt.legend([f'alpha_w={alpha_base}^{alpha_pow:.2f}' for alpha_pow in alpha_pows_w])
# # plt.ylim(best_performance-2.13,best_performance+.07)
# # plt.savefig(f'{figs_folder}agent_{agent_name}_episodes_{episode_count}_all_best.png')

plt.figure(4, figsize=(14,10))
plt.semilogx(alphas_theta, np.array(all_total_lasts).T, basex=alpha_base)
plt.title(f'Last {plot_count}-episode return average')
plt.xlabel('alpha')
plt.ylabel(f'Last {plot_count}-episode average reward')
plt.legend([f'alpha_w={alpha_base}^{alpha_pow:.2f}' for alpha_pow in alpha_pows_w])
plt.axhline(y=best_performance, linewidth=1, color="g", linestyle='--')
plt.ylim(best_performance-2.13,best_performance+.07)
# plt.savefig(f'{figs_folder}agent_{agent_name}_episodes_{episode_count}_all_last.png')

plt.show()

# %% [markdown]
# # REINFORCE with baseline Configs with other rewards

# %%
AgentClass = ReinforceWithBaselineAgent

alpha_base = 2
alpha_pows_w = np.linspace(-6, 0, 4)
alpha_pows_theta = np.linspace(-14, 0, 15)
alphas_w = np.power(alpha_base, alpha_pows_w)
alphas_theta = np.power(alpha_base, alpha_pows_theta)
print(alphas_w)
print(alphas_theta)

best_performance = -1.37
env = SmartVac(terminal_rewards=(-1,-3))
num_of_tests = 5
episode_count = 10000
plot_count = int(episode_count / 100)

agent_name = AgentClass.__name__

results = ""
all_best_avgs = []
all_best_alpha_thetas = []
all_total_avgs = []
all_total_bests = []
all_total_lasts = []
for alpha_pow_w in alpha_pows_w:
    all_avgs = []
    all_bests = []
    all_lasts = []
    alpha_w = np.power(alpha_base, alpha_pow_w)
    for alpha_pow_theta in alpha_pows_theta:
        alpha_theta = np.power(alpha_base, alpha_pow_theta)
        params_str = f'alpha_w_{alpha_w}_alpha_theta_{alpha_theta}_episodes_{episode_count}'
        mult_avgs = []
        for i_test in range(num_of_tests):
            print()
            print(i_test + 1, end=' ')

            # Initialize the agent
            agent = AgentClass(alpha_theta=alpha_theta, alpha_w=alpha_w)

            avgs = []
            probs1 = []
            probs2 = []

            episode_rewards = np.zeros(episode_count)
            for i_episode in range(episode_count):
                done = False
                totalReward = 0

                if i_episode >= plot_count and (i_episode % plot_count == 0):
                    avg = np.average(episode_rewards[i_episode - plot_count:i_episode])
                    avgs.append(avg)

                    # deterministic position
                    env.x = 0
                    env.y = 1
                    obs = env.get_obs()
                    prob = agent.get_action_vals_for_obs(obs)
                    probs1.append(prob)

                    # stochastic position
                    env.x = 1
                    env.y = 1
                    obs = env.get_obs()
                    prob = agent.get_action_vals_for_obs(obs)
                    probs2.append(prob)

                    print('#', end='', flush=True)
                    if len(avgs) % 100 == 0:
                        print(i_episode)

                obs = env.reset()
                action = agent.start(obs)

                step = 0
                while not done:
                    obs, reward, done = env.step(action)
                    action = agent.step(obs, reward, done)
                    totalReward += reward

                    step += 1
                    if step > max_episode_steps:
                        done = True

                episode_rewards[i_episode] = totalReward
                agent.update_for_episode()

            mult_avgs.append(avgs)

        avgs = np.mean(np.array(mult_avgs), axis=0)

        all_avgs.append(np.mean(avgs))
        all_bests.append(np.max(avgs))
        all_lasts.append(avgs[-1])

        results_tmp = f'\n\nAgent: {agent_name} \tAlpha_w: {alpha_w}\tAlpha_theta: {alpha_theta}'
        results_tmp += f'\nAverage: \t\t{np.mean(avgs):5.3f}'
        results_tmp += f'\nBest {plot_count} Average: \t{np.max(avgs):5.3f}'
        results_tmp += f'\nLast {plot_count} Average: \t{avgs[-1]:5.3f}'
        print(results_tmp)

        results += results_tmp
        
    # print best results
    all_avgs = np.array(all_avgs)
    idx = np.argmax(all_avgs)
    all_best_avgs.append(all_avgs[idx])
    all_best_alpha_thetas.append(alphas_theta[idx])
    
    # Save for plotting
    all_total_avgs.append(all_avgs)
    all_total_bests.append(all_bests)
    all_total_lasts.append(all_lasts)
    
# Print best results
all_best_avgs = np.array(all_best_avgs)
idx = np.argmax(all_best_avgs)
results += f'\n\n\nBest Average: {all_best_avgs[idx]}'
results += f'\nConfig: Alpha_w={alphas_w[idx]}, Alpha_theta={all_best_alpha_thetas[idx]}'

print('')
print(results)
# with open(f'{results_folder}agent_{agent_name}_all_mult.txt', 'w') as file:
#     file.write(results)
# Out:
# [0.015625 0.0625   0.25     1.      ]
# [6.10351562e-05 1.22070312e-04 2.44140625e-04 4.88281250e-04
#  9.76562500e-04 1.95312500e-03 3.90625000e-03 7.81250000e-03
#  1.56250000e-02 3.12500000e-02 6.25000000e-02 1.25000000e-01
#  2.50000000e-01 5.00000000e-01 1.00000000e+00]
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 6.103515625e-05
# Average: 			-2.941
# Best 100 Average: 	-2.807
# Last 100 Average: 	-2.913
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0001220703125
# Average: 			-2.865
# Best 100 Average: 	-2.659
# Last 100 Average: 	-2.797
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.000244140625
# Average: 			-2.747
# Best 100 Average: 	-2.477
# Last 100 Average: 	-2.540
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00048828125
# Average: 			-2.586
# Best 100 Average: 	-2.294
# Last 100 Average: 	-2.383
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0009765625
# Average: 			-2.375
# Best 100 Average: 	-1.941
# Last 100 Average: 	-2.005
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.001953125
# Average: 			-2.106
# Best 100 Average: 	-1.676
# Last 100 Average: 	-1.699
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00390625
# Average: 			-1.859
# Best 100 Average: 	-1.500
# Last 100 Average: 	-1.536
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0078125
# Average: 			-1.674
# Best 100 Average: 	-1.426
# Last 100 Average: 	-1.471
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.015625
# Average: 			-1.559
# Best 100 Average: 	-1.407
# Last 100 Average: 	-1.407
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.03125
# Average: 			-1.486
# Best 100 Average: 	-1.381
# Last 100 Average: 	-1.420
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0625
# Average: 			-1.447
# Best 100 Average: 	-1.366
# Last 100 Average: 	-1.395
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.125
# Average: 			-1.429
# Best 100 Average: 	-1.360
# Last 100 Average: 	-1.400
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.25
# Average: 			-1.986
# Best 100 Average: 	-1.771
# Last 100 Average: 	-1.980
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.5
# Average: 			-2.099
# Best 100 Average: 	-1.955
# Last 100 Average: 	-2.083
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 1.0
# Average: 			-2.806
# Best 100 Average: 	-2.091
# Last 100 Average: 	-2.236
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 6.103515625e-05
# Average: 			-2.950
# Best 100 Average: 	-2.783
# Last 100 Average: 	-2.834
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0001220703125
# Average: 			-2.877
# Best 100 Average: 	-2.653
# Last 100 Average: 	-2.759
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.000244140625
# Average: 			-2.751
# Best 100 Average: 	-2.485
# Last 100 Average: 	-2.490
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00048828125
# Average: 			-2.597
# Best 100 Average: 	-2.217
# Last 100 Average: 	-2.277
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0009765625
# Average: 			-2.377
# Best 100 Average: 	-1.994
# Last 100 Average: 	-1.994
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.001953125
# Average: 			-2.109
# Best 100 Average: 	-1.653
# Last 100 Average: 	-1.754
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00390625
# Average: 			-1.868
# Best 100 Average: 	-1.494
# Last 100 Average: 	-1.544
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0078125
# Average: 			-1.679
# Best 100 Average: 	-1.439
# Last 100 Average: 	-1.439
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.015625
# Average: 			-1.564
# Best 100 Average: 	-1.392
# Last 100 Average: 	-1.466
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.03125
# Average: 			-1.485
# Best 100 Average: 	-1.378
# Last 100 Average: 	-1.397
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0625
# Average: 			-1.446
# Best 100 Average: 	-1.366
# Last 100 Average: 	-1.402
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.125
# Average: 			-1.498
# Best 100 Average: 	-1.368
# Last 100 Average: 	-1.404
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.25
# Average: 			-1.815
# Best 100 Average: 	-1.510
# Last 100 Average: 	-1.884
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.5
# Average: 			-11.101
# Best 100 Average: 	-1.870
# Last 100 Average: 	-13.992
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 1.0
# Average: 			-6.396
# Best 100 Average: 	-4.258
# Last 100 Average: 	-5.359
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 6.103515625e-05
# Average: 			-2.950
# Best 100 Average: 	-2.770
# Last 100 Average: 	-2.821
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0001220703125
# Average: 			-2.877
# Best 100 Average: 	-2.644
# Last 100 Average: 	-2.751
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.000244140625
# Average: 			-2.751
# Best 100 Average: 	-2.525
# Last 100 Average: 	-2.615
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00048828125
# Average: 			-2.585
# Best 100 Average: 	-2.274
# Last 100 Average: 	-2.328
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0009765625
# Average: 			-2.374
# Best 100 Average: 	-1.898
# Last 100 Average: 	-2.067
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.001953125
# Average: 			-2.115
# Best 100 Average: 	-1.670
# Last 100 Average: 	-1.670
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00390625
# Average: 			-1.863
# Best 100 Average: 	-1.531
# Last 100 Average: 	-1.547
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0078125
# Average: 			-1.685
# Best 100 Average: 	-1.440
# Last 100 Average: 	-1.489
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.015625
# Average: 			-1.559
# Best 100 Average: 	-1.401
# Last 100 Average: 	-1.401
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.03125
# Average: 			-1.492
# Best 100 Average: 	-1.367
# Last 100 Average: 	-1.421
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0625
# Average: 			-1.440
# Best 100 Average: 	-1.354
# Last 100 Average: 	-1.401
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.125
# Average: 			-1.418
# Best 100 Average: 	-1.365
# Last 100 Average: 	-1.407
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.25
# Average: 			-1.421
# Best 100 Average: 	-1.356
# Last 100 Average: 	-1.377
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.5
# Average: 			-2.480
# Best 100 Average: 	-1.642
# Last 100 Average: 	-11.367
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 1.0
# Average: 			-13.782
# Best 100 Average: 	-4.897
# Last 100 Average: 	-14.785
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 6.103515625e-05
# Average: 			-2.947
# Best 100 Average: 	-2.747
# Last 100 Average: 	-2.861
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0001220703125
# Average: 			-2.866
# Best 100 Average: 	-2.656
# Last 100 Average: 	-2.748
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.000244140625
# Average: 			-2.748
# Best 100 Average: 	-2.500
# Last 100 Average: 	-2.514
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00048828125
# Average: 			-2.587
# Best 100 Average: 	-2.288
# Last 100 Average: 	-2.318
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0009765625
# Average: 			-2.376
# Best 100 Average: 	-1.957
# Last 100 Average: 	-2.043
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.001953125
# Average: 			-2.106
# Best 100 Average: 	-1.673
# Last 100 Average: 	-1.768
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00390625
# Average: 			-1.867
# Best 100 Average: 	-1.508
# Last 100 Average: 	-1.539
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0078125
# Average: 			-1.682
# Best 100 Average: 	-1.436
# Last 100 Average: 	-1.472
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.015625
# Average: 			-1.554
# Best 100 Average: 	-1.396
# Last 100 Average: 	-1.412
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.03125
# Average: 			-1.492
# Best 100 Average: 	-1.375
# Last 100 Average: 	-1.401
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0625
# Average: 			-1.445
# Best 100 Average: 	-1.364
# Last 100 Average: 	-1.385
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.125
# Average: 			-1.422
# Best 100 Average: 	-1.366
# Last 100 Average: 	-1.367
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.25
# Average: 			-1.638
# Best 100 Average: 	-1.552
# Last 100 Average: 	-1.628
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.5
# Average: 			-1.525
# Best 100 Average: 	-1.459
# Last 100 Average: 	-1.531
#
# 1 ###################################################################################################
# 2 ###################################################################################################
# 3 ###################################################################################################
# 4 ###################################################################################################
# 5 ###################################################################################################
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 1.0
# Average: 			-1.991
# Best 100 Average: 	-1.911
# Last 100 Average: 	-1.928
#
#
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 6.103515625e-05
# Average: 			-2.941
# Best 100 Average: 	-2.807
# Last 100 Average: 	-2.913
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0001220703125
# Average: 			-2.865
# Best 100 Average: 	-2.659
# Last 100 Average: 	-2.797
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.000244140625
# Average: 			-2.747
# Best 100 Average: 	-2.477
# Last 100 Average: 	-2.540
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00048828125
# Average: 			-2.586
# Best 100 Average: 	-2.294
# Last 100 Average: 	-2.383
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0009765625
# Average: 			-2.375
# Best 100 Average: 	-1.941
# Last 100 Average: 	-2.005
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.001953125
# Average: 			-2.106
# Best 100 Average: 	-1.676
# Last 100 Average: 	-1.699
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.00390625
# Average: 			-1.859
# Best 100 Average: 	-1.500
# Last 100 Average: 	-1.536
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0078125
# Average: 			-1.674
# Best 100 Average: 	-1.426
# Last 100 Average: 	-1.471
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.015625
# Average: 			-1.559
# Best 100 Average: 	-1.407
# Last 100 Average: 	-1.407
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.03125
# Average: 			-1.486
# Best 100 Average: 	-1.381
# Last 100 Average: 	-1.420
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.0625
# Average: 			-1.447
# Best 100 Average: 	-1.366
# Last 100 Average: 	-1.395
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.125
# Average: 			-1.429
# Best 100 Average: 	-1.360
# Last 100 Average: 	-1.400
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.25
# Average: 			-1.986
# Best 100 Average: 	-1.771
# Last 100 Average: 	-1.980
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 0.5
# Average: 			-2.099
# Best 100 Average: 	-1.955
# Last 100 Average: 	-2.083
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.015625	Alpha_theta: 1.0
# Average: 			-2.806
# Best 100 Average: 	-2.091
# Last 100 Average: 	-2.236
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 6.103515625e-05
# Average: 			-2.950
# Best 100 Average: 	-2.783
# Last 100 Average: 	-2.834
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0001220703125
# Average: 			-2.877
# Best 100 Average: 	-2.653
# Last 100 Average: 	-2.759
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.000244140625
# Average: 			-2.751
# Best 100 Average: 	-2.485
# Last 100 Average: 	-2.490
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00048828125
# Average: 			-2.597
# Best 100 Average: 	-2.217
# Last 100 Average: 	-2.277
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0009765625
# Average: 			-2.377
# Best 100 Average: 	-1.994
# Last 100 Average: 	-1.994
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.001953125
# Average: 			-2.109
# Best 100 Average: 	-1.653
# Last 100 Average: 	-1.754
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.00390625
# Average: 			-1.868
# Best 100 Average: 	-1.494
# Last 100 Average: 	-1.544
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0078125
# Average: 			-1.679
# Best 100 Average: 	-1.439
# Last 100 Average: 	-1.439
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.015625
# Average: 			-1.564
# Best 100 Average: 	-1.392
# Last 100 Average: 	-1.466
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.03125
# Average: 			-1.485
# Best 100 Average: 	-1.378
# Last 100 Average: 	-1.397
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.0625
# Average: 			-1.446
# Best 100 Average: 	-1.366
# Last 100 Average: 	-1.402
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.125
# Average: 			-1.498
# Best 100 Average: 	-1.368
# Last 100 Average: 	-1.404
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.25
# Average: 			-1.815
# Best 100 Average: 	-1.510
# Last 100 Average: 	-1.884
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 0.5
# Average: 			-11.101
# Best 100 Average: 	-1.870
# Last 100 Average: 	-13.992
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.0625	Alpha_theta: 1.0
# Average: 			-6.396
# Best 100 Average: 	-4.258
# Last 100 Average: 	-5.359
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 6.103515625e-05
# Average: 			-2.950
# Best 100 Average: 	-2.770
# Last 100 Average: 	-2.821
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0001220703125
# Average: 			-2.877
# Best 100 Average: 	-2.644
# Last 100 Average: 	-2.751
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.000244140625
# Average: 			-2.751
# Best 100 Average: 	-2.525
# Last 100 Average: 	-2.615
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00048828125
# Average: 			-2.585
# Best 100 Average: 	-2.274
# Last 100 Average: 	-2.328
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0009765625
# Average: 			-2.374
# Best 100 Average: 	-1.898
# Last 100 Average: 	-2.067
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.001953125
# Average: 			-2.115
# Best 100 Average: 	-1.670
# Last 100 Average: 	-1.670
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.00390625
# Average: 			-1.863
# Best 100 Average: 	-1.531
# Last 100 Average: 	-1.547
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0078125
# Average: 			-1.685
# Best 100 Average: 	-1.440
# Last 100 Average: 	-1.489
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.015625
# Average: 			-1.559
# Best 100 Average: 	-1.401
# Last 100 Average: 	-1.401
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.03125
# Average: 			-1.492
# Best 100 Average: 	-1.367
# Last 100 Average: 	-1.421
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.0625
# Average: 			-1.440
# Best 100 Average: 	-1.354
# Last 100 Average: 	-1.401
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.125
# Average: 			-1.418
# Best 100 Average: 	-1.365
# Last 100 Average: 	-1.407
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.25
# Average: 			-1.421
# Best 100 Average: 	-1.356
# Last 100 Average: 	-1.377
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 0.5
# Average: 			-2.480
# Best 100 Average: 	-1.642
# Last 100 Average: 	-11.367
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 0.25	Alpha_theta: 1.0
# Average: 			-13.782
# Best 100 Average: 	-4.897
# Last 100 Average: 	-14.785
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 6.103515625e-05
# Average: 			-2.947
# Best 100 Average: 	-2.747
# Last 100 Average: 	-2.861
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0001220703125
# Average: 			-2.866
# Best 100 Average: 	-2.656
# Last 100 Average: 	-2.748
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.000244140625
# Average: 			-2.748
# Best 100 Average: 	-2.500
# Last 100 Average: 	-2.514
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00048828125
# Average: 			-2.587
# Best 100 Average: 	-2.288
# Last 100 Average: 	-2.318
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0009765625
# Average: 			-2.376
# Best 100 Average: 	-1.957
# Last 100 Average: 	-2.043
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.001953125
# Average: 			-2.106
# Best 100 Average: 	-1.673
# Last 100 Average: 	-1.768
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.00390625
# Average: 			-1.867
# Best 100 Average: 	-1.508
# Last 100 Average: 	-1.539
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0078125
# Average: 			-1.682
# Best 100 Average: 	-1.436
# Last 100 Average: 	-1.472
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.015625
# Average: 			-1.554
# Best 100 Average: 	-1.396
# Last 100 Average: 	-1.412
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.03125
# Average: 			-1.492
# Best 100 Average: 	-1.375
# Last 100 Average: 	-1.401
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.0625
# Average: 			-1.445
# Best 100 Average: 	-1.364
# Last 100 Average: 	-1.385
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.125
# Average: 			-1.422
# Best 100 Average: 	-1.366
# Last 100 Average: 	-1.367
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.25
# Average: 			-1.638
# Best 100 Average: 	-1.552
# Last 100 Average: 	-1.628
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 0.5
# Average: 			-1.525
# Best 100 Average: 	-1.459
# Last 100 Average: 	-1.531
#
# Agent: ReinforceWithBaselineAgent 	Alpha_w: 1.0	Alpha_theta: 1.0
# Average: 			-1.991
# Best 100 Average: 	-1.911
# Last 100 Average: 	-1.928
#
#
# Best Average: -1.418238383838384
# Config: Alpha_w=0.25, Alpha_theta=0.125

# %%
plt.figure(2, figsize=(14,10))
plt.semilogx(alphas_theta, np.array(all_total_avgs).T, basex=alpha_base)
plt.title(f'Average Return in {episode_count} episodes')
plt.xlabel('alpha_theta')
plt.ylabel('Average Return')
plt.legend([f'alpha_w={alpha_base}^{alpha_pow:.2f}' for alpha_pow in alpha_pows_w])
plt.axhline(y=best_performance, linewidth=1, color="g", linestyle='--')
plt.ylim(best_performance-2.13,best_performance+.07)
# plt.savefig(f'{figs_folder}agent_{agent_name}_episodes_{episode_count}_all_avg.png')

# There is no meaning in bests plot
# plt.figure(3, figsize=(14,10))
# plt.semilogx(alphas_theta, np.array(all_total_bests).T, basex=alpha_base)
# plt.title(f'Best {plot_count}-episode return average until {episode_count} episodes')
# plt.xlabel('alpha')
# plt.ylabel(f'Best {plot_count}-episode average reward')
# plt.axhline(y=best_performance, linewidth=1, color="g", linestyle='--')
# plt.legend([f'alpha_w={alpha_base}^{alpha_pow:.2f}' for alpha_pow in alpha_pows_w])
# # plt.ylim(best_performance-2.13,best_performance+.07)
# # plt.savefig(f'{figs_folder}agent_{agent_name}_episodes_{episode_count}_all_best.png')

plt.figure(4, figsize=(14,10))
plt.semilogx(alphas_theta, np.array(all_total_lasts).T, basex=alpha_base)
plt.title(f'Last {plot_count}-episode return average')
plt.xlabel('alpha')
plt.ylabel(f'Last {plot_count}-episode average reward')
plt.legend([f'alpha_w={alpha_base}^{alpha_pow:.2f}' for alpha_pow in alpha_pows_w])
plt.axhline(y=best_performance, linewidth=1, color="g", linestyle='--')
plt.ylim(best_performance-2.13,best_performance+.07)
# plt.savefig(f'{figs_folder}agent_{agent_name}_episodes_{episode_count}_all_last.png')

plt.show()
